# %%
with open('DAY3.txt') as file:
  rucksacks = [i for i in file.read().strip().split("\n")]

  rucksackLengths = (lambda x:[len(i) for i in x])(rucksacks)

  #Compartment1, Compartment2 = rucksacks[:len(i)//2], rucksacks[len(i)//2:]
  
#print(rucksacks[1])


def LetterConverter(Array):
    
    for k in range (len(Array)):
        Array[k] = ord(Array[k]) - 96

        if Array[k] < 0:
            Array[k] = Array[k] + 58
    return Array

    
Compartment1_Score = []
Compartment2_Score = []



i = 0
for i in range (len(rucksacks)):
    Compartment1, Compartment2 = rucksacks[i][:len(rucksacks[i])//2], rucksacks[i][len(rucksacks[i])//2:]

    Compartment1 = [*Compartment1]
    Compartment2 = [*Compartment2]
    j=0
    

    

    for x in range (len(Compartment1[i])):
        if Compartment1[x] == Compartment2[i][x]:
            print(Compartment1[x])











    # for Compartment in range ("Compartment1","Compartment2"):
        
    #     Compartment = ord(Compartment1[i]) - 96

    #     if Compartment < 0:
    #         Compartment = Compartment + 58
        
        







    # k=0

    # while k < len(Compartment2):
    #     Compartment2Scores = ord(Compartment2[k]) - 96
    #     if Compartment2Scores < 0:
    #         Compartment2Scores = Compartment2Scores + 58
        
    #     k = k+1
        
    # print(Compartment1Scores,Compartment2Scores)



    
    #print(Compartment1, Compartment2)
    #print(Compartment1_Score)
    #print(Compartment1,Compartment2)
